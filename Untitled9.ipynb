# %%
# !git clone https://github.com/ttiagojm/fast-denser3.git
# Out:
# Cloning into 'fast-denser3'...
# remote: Enumerating objects: 452, done.
# remote: Counting objects: 100% (181/181), done.
# remote: Compressing objects: 100% (104/104), done.
# remote: Total 452 (delta 136), reused 114 (delta 77), pack-reused 271
# Receiving objects: 100% (452/452), 88.57 KiB | 1.38 MiB/s, done.
# Resolving deltas: 100% (298/298), done.

# %%
# %cd fast-denser3/f-denser/
# Out:
# /content/fast-denser3/f-denser

# %%
# !python setup.py install
# !pip install jsmin
# Out:
# running install
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# creating Fast_DENSER.egg-info
# writing Fast_DENSER.egg-info/PKG-INFO
# writing dependency_links to Fast_DENSER.egg-info/dependency_links.txt
# writing top-level names to Fast_DENSER.egg-info/top_level.txt
# writing manifest file 'Fast_DENSER.egg-info/SOURCES.txt'
# reading manifest file 'Fast_DENSER.egg-info/SOURCES.txt'
# writing manifest file 'Fast_DENSER.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/fast_denser
# copying fast_denser/utils.py -> build/lib/fast_denser
# copying fast_denser/grammar.py -> build/lib/fast_denser
# copying fast_denser/engine.py -> build/lib/fast_denser
# copying fast_denser/__init__.py -> build/lib/fast_denser
# creating build/lib/tests
# copying tests/test_datasets.py -> build/lib/tests
# copying tests/test_time_stop.py -> build/lib/tests
# copying tests/test_grammar.py -> build/lib/tests
# copying tests/test_utils.py -> build/lib/tests
# copying tests/test_utils_3.py -> build/lib/tests
# copying tests/test_fitness_metrics.py -> build/lib/tests
# copying tests/test_utils_2.py -> build/lib/tests
# copying tests/__init__.py -> build/lib/tests
# creating build/lib/fast_denser/utilities
# copying fast_denser/utilities/data.py -> build/lib/fast_denser/utilities
# copying fast_denser/utilities/fitness_metrics.py -> build/lib/fast_denser/utilities
# copying fast_denser/utilities/__init__.py -> build/lib/fast_denser/utilities
# copying fast_denser/utilities/data_augmentation.py -> build/lib/fast_denser/utilities
# creating build/lib/fast_denser/utilities/datasets
# copying fast_denser/utilities/datasets/tiny_imagenet.py -> build/lib/fast_denser/utilities/datasets
# copying fast_denser/utilities/datasets/cifar.py -> build/lib/fast_denser/utilities/datasets
# copying fast_denser/utilities/datasets/svhn.py -> build/lib/fast_denser/utilities/datasets
# copying fast_denser/utilities/datasets/__init__.py -> build/lib/fast_denser/utilities/datasets
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/fast_denser
# copying build/lib/fast_denser/utils.py -> build/bdist.linux-x86_64/egg/fast_denser
# copying build/lib/fast_denser/grammar.py -> build/bdist.linux-x86_64/egg/fast_denser
# creating build/bdist.linux-x86_64/egg/fast_denser/utilities
# copying build/lib/fast_denser/utilities/data.py -> build/bdist.linux-x86_64/egg/fast_denser/utilities
# copying build/lib/fast_denser/utilities/fitness_metrics.py -> build/bdist.linux-x86_64/egg/fast_denser/utilities
# creating build/bdist.linux-x86_64/egg/fast_denser/utilities/datasets
# copying build/lib/fast_denser/utilities/datasets/tiny_imagenet.py -> build/bdist.linux-x86_64/egg/fast_denser/utilities/datasets
# copying build/lib/fast_denser/utilities/datasets/cifar.py -> build/bdist.linux-x86_64/egg/fast_denser/utilities/datasets
# copying build/lib/fast_denser/utilities/datasets/svhn.py -> build/bdist.linux-x86_64/egg/fast_denser/utilities/datasets
# copying build/lib/fast_denser/utilities/datasets/__init__.py -> build/bdist.linux-x86_64/egg/fast_denser/utilities/datasets
# copying build/lib/fast_denser/utilities/__init__.py -> build/bdist.linux-x86_64/egg/fast_denser/utilities
# copying build/lib/fast_denser/utilities/data_augmentation.py -> build/bdist.linux-x86_64/egg/fast_denser/utilities
# copying build/lib/fast_denser/engine.py -> build/bdist.linux-x86_64/egg/fast_denser
# copying build/lib/fast_denser/__init__.py -> build/bdist.linux-x86_64/egg/fast_denser
# creating build/bdist.linux-x86_64/egg/tests
# copying build/lib/tests/test_datasets.py -> build/bdist.linux-x86_64/egg/tests
# copying build/lib/tests/test_time_stop.py -> build/bdist.linux-x86_64/egg/tests
# copying build/lib/tests/test_grammar.py -> build/bdist.linux-x86_64/egg/tests
# copying build/lib/tests/test_utils.py -> build/bdist.linux-x86_64/egg/tests
# copying build/lib/tests/test_utils_3.py -> build/bdist.linux-x86_64/egg/tests
# copying build/lib/tests/test_fitness_metrics.py -> build/bdist.linux-x86_64/egg/tests
# copying build/lib/tests/test_utils_2.py -> build/bdist.linux-x86_64/egg/tests
# copying build/lib/tests/__init__.py -> build/bdist.linux-x86_64/egg/tests
# byte-compiling build/bdist.linux-x86_64/egg/fast_denser/utils.py to utils.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fast_denser/grammar.py to grammar.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fast_denser/utilities/data.py to data.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fast_denser/utilities/fitness_metrics.py to fitness_metrics.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fast_denser/utilities/datasets/tiny_imagenet.py to tiny_imagenet.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fast_denser/utilities/datasets/cifar.py to cifar.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fast_denser/utilities/datasets/svhn.py to svhn.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fast_denser/utilities/datasets/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fast_denser/utilities/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fast_denser/utilities/data_augmentation.py to data_augmentation.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fast_denser/engine.py to engine.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fast_denser/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tests/test_datasets.py to test_datasets.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tests/test_time_stop.py to test_time_stop.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tests/test_grammar.py to test_grammar.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tests/test_utils.py to test_utils.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tests/test_utils_3.py to test_utils_3.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tests/test_fitness_metrics.py to test_fitness_metrics.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tests/test_utils_2.py to test_utils_2.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tests/__init__.py to __init__.cpython-310.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying Fast_DENSER.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying Fast_DENSER.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying Fast_DENSER.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying Fast_DENSER.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# creating dist
# creating 'dist/Fast_DENSER-2.1.0-py3.10.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing Fast_DENSER-2.1.0-py3.10.egg
# Copying Fast_DENSER-2.1.0-py3.10.egg to /usr/local/lib/python3.10/dist-packages
# Adding Fast-DENSER 2.1.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.10/dist-packages/Fast_DENSER-2.1.0-py3.10.egg
# Processing dependencies for Fast-DENSER==2.1.0
# Finished processing dependencies for Fast-DENSER==2.1.0
# Collecting jsmin
#   Downloading jsmin-3.0.1.tar.gz (13 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: jsmin
#   Building wheel for jsmin (setup.py) ... done
#   Created wheel for jsmin: filename=jsmin-3.0.1-py3-none-any.whl size=13765 sha256=f6b375dadac6d560fcc87ddf1ced34b04bd9634d27ac7949c87e823d5f5baedb
#   Stored in directory: /root/.cache/pip/wheels/9a/eb/65/4a07a200d454fb40cbd51a2deee3c5d26285321e3bbbe627a5
# Successfully built jsmin
# Installing collected packages: jsmin
# Successfully installed jsmin-3.0.1

# %%
import fast_denser

# %%
fast_denser.search(0, 'cifar10', '../example/config.json', '../example/cnn.grammar')
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 4s 0us/step
# [0] Creating the initial population
# [0] Performing generation: 0
# {'trainable_parameters': 16962, 'accuracy_test': -inf}
# {'trainable_parameters': 462530, 'accuracy_test': -inf}
# {'trainable_parameters': 1807877, 'accuracy_test': 1672.0296630859375}
# {'trainable_parameters': 436086, 'accuracy_test': -inf}
# [0] Best fitness of generation 0: 1672.029663
# [0] Best overall fitness: 1672.029663
# [0] Performing generation: 1
# {'trainable_parameters': 1807877, 'accuracy_test': 1684.762451171875}
# {'trainable_parameters': 1206982, 'accuracy_test': 1612.106201171875}
# {'trainable_parameters': 1807877, 'accuracy_test': 1509.340576171875}
# {'trainable_parameters': 1807877, 'accuracy_test': 3222.017822265625}
# {'trainable_parameters': 1807877, 'accuracy_test': 1686.751220703125}
# [0] Best fitness of generation 1: 3222.017822
# [0] Best overall fitness: 3222.017822
# [0] Performing generation: 2
# {'trainable_parameters': 1807877, 'accuracy_test': 3224.34423828125}
# {'trainable_parameters': 2480482, 'accuracy_test': 3329.48291015625}
# {'trainable_parameters': 3605699, 'accuracy_test': 3363.63916015625}
# {'trainable_parameters': 3206183, 'accuracy_test': 3342.853515625}
# {'trainable_parameters': 2109255, 'accuracy_test': 3067.4326171875}
# [0] Best fitness of generation 2: 3363.639160
# [0] Best overall fitness: 3363.639160
# [0] Performing generation: 3
# {'trainable_parameters': 3605699, 'accuracy_test': 3328.44189453125}
# {'trainable_parameters': 2413954, 'accuracy_test': 3153.755859375}
# {'trainable_parameters': 3605699, 'accuracy_test': 3329.04638671875}
# {'trainable_parameters': 3239666, 'accuracy_test': 3399.263671875}
# {'trainable_parameters': 48733759, 'accuracy_test': 3410.9189453125}
# [0] Best fitness of generation 3: 3410.918945
# [0] Best overall fitness: 3410.918945
# [0] Performing generation: 4
# {'trainable_parameters': 48733759, 'accuracy_test': 3409.4921875}
# {'trainable_parameters': 48733759, 'accuracy_test': 3445.55908203125}
# {'trainable_parameters': 48733759, 'accuracy_test': 3627.911376953125}
# {'trainable_parameters': 992800, 'accuracy_test': 1370.5263671875}
# {'trainable_parameters': 48733759, 'accuracy_test': 3414.227783203125}
# [0] Best fitness of generation 4: 3627.911377
# [0] Best overall fitness: 3627.911377
# [0] Performing generation: 5
# {'trainable_parameters': 48733759, 'accuracy_test': 3627.466796875}
# {'trainable_parameters': 48733759, 'accuracy_test': 3748.2265625}
# {'trainable_parameters': 52661943, 'accuracy_test': 3539.631103515625}
# {'trainable_parameters': 48733759, 'accuracy_test': 3620.08642578125}
# {'trainable_parameters': 48733759, 'accuracy_test': 3637.08056640625}
# [0] Best fitness of generation 5: 3748.226562
# [0] Best overall fitness: 3748.226562
# [0] Performing generation: 6
# {'trainable_parameters': 48733759, 'accuracy_test': 3747.8759765625}
# {'trainable_parameters': 48733759, 'accuracy_test': 3760.675048828125}
# {'trainable_parameters': 48733759, 'accuracy_test': 3757.610107421875}
# {'trainable_parameters': 48733759, 'accuracy_test': 3743.349365234375}
# {'trainable_parameters': 48733759, 'accuracy_test': 3742.3623046875}
# {'trainable_parameters': 48733759, 'accuracy_test': 3752.16552734375}
# [0] Best fitness of generation 6: 3760.675049
# [0] Best overall fitness: 3760.675049
# [0] Performing generation: 7
# {'trainable_parameters': 48733759, 'accuracy_test': 3758.2822265625}
# {'trainable_parameters': 48733759, 'accuracy_test': 3762.488525390625}
# {'trainable_parameters': 48733759, 'accuracy_test': 3760.139892578125}
# {'trainable_parameters': 42341575, 'accuracy_test': 3674.26025390625}
# {'trainable_parameters': 48733759, 'accuracy_test': 3573.697265625}
# [0] Best fitness of generation 7: 3762.488525
# [0] Best overall fitness: 3762.488525
# [0] Performing generation: 8
# {'trainable_parameters': 48733759, 'accuracy_test': 3769.198486328125}
# {'trainable_parameters': 48733759, 'accuracy_test': 3763.610595703125}
# {'trainable_parameters': 51291373, 'accuracy_test': 3746.80126953125}
# {'trainable_parameters': 2332043, 'accuracy_test': 3600.2001953125}
# {'trainable_parameters': 48733759, 'accuracy_test': 3757.0439453125}
# [0] Best fitness of generation 8: 3769.198486
# [0] Best overall fitness: 3769.198486
# [0] Performing generation: 9
# {'trainable_parameters': 48733759, 'accuracy_test': 3767.518310546875}
# {'trainable_parameters': 48733759, 'accuracy_test': 3743.179931640625}
# {'trainable_parameters': 198057608, 'accuracy_test': 3761.025634765625}
# {'trainable_parameters': 47950644, 'accuracy_test': 3617.820068359375}
# {'trainable_parameters': 48733759, 'accuracy_test': 3746.249267578125}
# [0] Best fitness of generation 9: 3767.518311
# [0] Best overall fitness: 3769.198486
# [0] Performing generation: 10
# {'trainable_parameters': 48733759, 'accuracy_test': 3752.461181640625}
# {'trainable_parameters': 48733759, 'accuracy_test': 3769.921630859375}
# {'trainable_parameters': 48733968, 'accuracy_test': 3758.673095703125}
# {'trainable_parameters': 48733759, 'accuracy_test': 3754.6318359375}
# {'trainable_parameters': 48733759, 'accuracy_test': 3752.48291015625}
# {'trainable_parameters': 48733759, 'accuracy_test': 3763.301025390625}
# [0] Best fitness of generation 10: 3769.921631
# [0] Best overall fitness: 3769.921631
# [0] Performing generation: 11
# {'trainable_parameters': 48733759, 'accuracy_test': 3759.517822265625}
# {'trainable_parameters': 48733759, 'accuracy_test': 3772.57373046875}
# {'trainable_parameters': 48733759, 'accuracy_test': 3753.390625}
# {'trainable_parameters': 48983951, 'accuracy_test': 3780.292724609375}
# {'trainable_parameters': 47950644, 'accuracy_test': 3617.9658203125}
# [0] Best fitness of generation 11: 3780.292725
# [0] Best overall fitness: 3780.292725
# [0] Performing generation: 12
# {'trainable_parameters': 48983951, 'accuracy_test': 3771.243896484375}
# {'trainable_parameters': 48983951, 'accuracy_test': 3773.7578125}
# {'trainable_parameters': 216628660, 'accuracy_test': 3786.321533203125}
# {'trainable_parameters': 6939861, 'accuracy_test': 3239.695068359375}
# {'trainable_parameters': 48983951, 'accuracy_test': 3775.456298828125}
# [0] Best fitness of generation 12: 3786.321533
# [0] Best overall fitness: 3786.321533
# [0] Performing generation: 13
# {'trainable_parameters': 216628660, 'accuracy_test': 3784.02099609375}
# {'trainable_parameters': 177529314, 'accuracy_test': 3688.115234375}
# {'trainable_parameters': 55606225, 'accuracy_test': 3798.439453125}
# {'trainable_parameters': 216824365, 'accuracy_test': 3673.781494140625}
# {'trainable_parameters': 16038746, 'accuracy_test': 3584.603271484375}
# [0] Best fitness of generation 13: 3798.439453
# [0] Best overall fitness: 3798.439453
# [0] Performing generation: 14
# {'trainable_parameters': 55606225, 'accuracy_test': 3789.55908203125}
# {'trainable_parameters': 7921225, 'accuracy_test': 3044.074462890625}
# {'trainable_parameters': 55606225, 'accuracy_test': 3784.822265625}
# {'trainable_parameters': 55606225, 'accuracy_test': 3797.946533203125}
# {'trainable_parameters': 8758789, 'accuracy_test': 1254.4794921875}
# [0] Best fitness of generation 14: 3797.946533
# [0] Best overall fitness: 3798.439453
# [0] Performing generation: 15
# {'trainable_parameters': 55606225, 'accuracy_test': 3788.84375}
# {'trainable_parameters': 6786502, 'accuracy_test': 3794.26416015625}
# {'trainable_parameters': 57087570, 'accuracy_test': 3781.725341796875}
# {'trainable_parameters': 58901495, 'accuracy_test': 3791.01123046875}
# {'trainable_parameters': 49113895, 'accuracy_test': 3796.26904296875}
# [0] Best fitness of generation 15: 3796.269043
# [0] Best overall fitness: 3798.439453
# [0] Performing generation: 16
# {'trainable_parameters': 49113895, 'accuracy_test': 3795.867919921875}
# {'trainable_parameters': 49113895, 'accuracy_test': 3782.883544921875}
# {'trainable_parameters': 17531566, 'accuracy_test': 3792.527099609375}
# {'trainable_parameters': 49113895, 'accuracy_test': 3897.6103515625}
# {'trainable_parameters': 49946740, 'accuracy_test': 3776.671630859375}
# [0] Best fitness of generation 16: 3897.610352
# [0] Best overall fitness: 3897.610352
# [0] Performing generation: 17
# {'trainable_parameters': 49113895, 'accuracy_test': 3901.1865234375}
# {'trainable_parameters': 2509695, 'accuracy_test': 3813.671142578125}
# {'trainable_parameters': 57625400, 'accuracy_test': 3874.0517578125}
# {'trainable_parameters': 49113895, 'accuracy_test': 3897.85302734375}
# {'trainable_parameters': 4605880, 'accuracy_test': 1267.0452880859375}
# [0] Best fitness of generation 17: 3901.186523
# [0] Best overall fitness: 3901.186523
# [0] Performing generation: 18
# {'trainable_parameters': 49113895, 'accuracy_test': 3896.7890625}
# {'trainable_parameters': 190479145, 'accuracy_test': 3495.012939453125}
# {'trainable_parameters': 74232715, 'accuracy_test': 3791.41845703125}
# {'trainable_parameters': 50505621, 'accuracy_test': 3792.961669921875}
# {'trainable_parameters': 6024620, 'accuracy_test': 3273.399169921875}
# [0] Best fitness of generation 18: 3896.789062
# [0] Best overall fitness: 3901.186523
# [0] Performing generation: 19
# {'trainable_parameters': 49113895, 'accuracy_test': 3895.025634765625}
# {'trainable_parameters': 5343025, 'accuracy_test': 3765.859375}
# {'trainable_parameters': 49113895, 'accuracy_test': 3894.513916015625}
# {'trainable_parameters': 1922852, 'accuracy_test': 3803.02978515625}
# {'trainable_parameters': 49113895, 'accuracy_test': 3780.765869140625}
# [0] Best fitness of generation 19: 3895.025635
# [0] Best overall fitness: 3901.186523
# [0] Performing generation: 20
# {'trainable_parameters': 49113895, 'accuracy_test': 3891.027099609375}
# {'trainable_parameters': 49113907, 'accuracy_test': 3936.4599609375}
# {'trainable_parameters': 7227661, 'accuracy_test': 3899.44189453125}
# {'trainable_parameters': 11777955, 'accuracy_test': 3889.00830078125}
# {'trainable_parameters': 49113895, 'accuracy_test': 3897.68994140625}
# [0] Best fitness of generation 20: 3936.459961
# [0] Best overall fitness: 3936.459961
# [0] Performing generation: 21
# {'trainable_parameters': 49113907, 'accuracy_test': 3937.494140625}
# {'trainable_parameters': 9904552, 'accuracy_test': 3078.5302734375}
# {'trainable_parameters': 49114843, 'accuracy_test': 3768.513916015625}
# {'trainable_parameters': 49113907, 'accuracy_test': 3942.408447265625}
# {'trainable_parameters': 55717759, 'accuracy_test': 3793.932373046875}
# {'trainable_parameters': 49113907, 'accuracy_test': 3933.807861328125}
# [0] Best fitness of generation 21: 3942.408447
# [0] Best overall fitness: 3942.408447
# [0] Performing generation: 22
# {'trainable_parameters': 49113907, 'accuracy_test': 3937.4873046875}
# {'trainable_parameters': 49114727, 'accuracy_test': 3814.400146484375}
# {'trainable_parameters': 11480337, 'accuracy_test': 3652.61669921875}
# {'trainable_parameters': 49113702, 'accuracy_test': 3937.524658203125}
# {'trainable_parameters': 49114831, 'accuracy_test': 3884.411376953125}
# [0] Best fitness of generation 22: 3937.524658
# [0] Best overall fitness: 3942.408447
# [0] Performing generation: 23
# {'trainable_parameters': 49113702, 'accuracy_test': 3939.98828125}
# {'trainable_parameters': 55606984, 'accuracy_test': 3951.142578125}
# {'trainable_parameters': 43040232, 'accuracy_test': 3938.52294921875}
# {'trainable_parameters': 49113714, 'accuracy_test': 3809.734619140625}
# {'trainable_parameters': 49113702, 'accuracy_test': 3938.451904296875}
# [0] Best fitness of generation 23: 3951.142578
# [0] Best overall fitness: 3951.142578
# [0] Performing generation: 24
# {'trainable_parameters': 55606984, 'accuracy_test': 3952.02392578125}
# {'trainable_parameters': 5342832, 'accuracy_test': 3026.49365234375}
# {'trainable_parameters': 9595643, 'accuracy_test': 3287.050048828125}
# {'trainable_parameters': 55606984, 'accuracy_test': 3953.4609375}
# {'trainable_parameters': 54832400, 'accuracy_test': 3812.76220703125}
# {'trainable_parameters': 55606984, 'accuracy_test': 3949.47314453125}
# [0] Best fitness of generation 24: 3953.460938
# [0] Best overall fitness: 3953.460938
# [0] Performing generation: 25
# {'trainable_parameters': 55606984, 'accuracy_test': 3951.671875}
# {'trainable_parameters': 216450864, 'accuracy_test': 3960.480224609375}
# {'trainable_parameters': 2510454, 'accuracy_test': 3949.081787109375}
# {'trainable_parameters': 69147548, 'accuracy_test': 3914.9619140625}
# {'trainable_parameters': 55607686, 'accuracy_test': 3950.6708984375}
# [0] Best fitness of generation 25: 3960.480225
# [0] Best overall fitness: 3960.480225
# [0] Performing generation: 26
# {'trainable_parameters': 216450864, 'accuracy_test': 3958.6044921875}
# {'trainable_parameters': 216449224, 'accuracy_test': 3848.714111328125}
# {'trainable_parameters': 2494966, 'accuracy_test': 3242.1220703125}
# {'trainable_parameters': 216450864, 'accuracy_test': 3960.251708984375}
# {'trainable_parameters': 216451102, 'accuracy_test': 3959.375244140625}
# {'trainable_parameters': 216450864, 'accuracy_test': 3958.764892578125}
# [0] Best fitness of generation 26: 3960.251709
# [0] Best overall fitness: 3960.480225
# [0] Performing generation: 27
# {'trainable_parameters': 216450864, 'accuracy_test': 3960.55908203125}
# {'trainable_parameters': 216450864, 'accuracy_test': 3960.483642578125}
# {'trainable_parameters': 47967337, 'accuracy_test': 3243.541259765625}
# {'trainable_parameters': 27335574, 'accuracy_test': 3680.25244140625}
